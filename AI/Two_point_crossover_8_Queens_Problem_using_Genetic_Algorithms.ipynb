# %% [markdown]
# ## Today's Agenda

# %% [markdown]
# #### 1. Explore the 8-Queens Problem from an implementation Perspective
# #### 2. How to formulate the Solution for 8-Queens Problem
# #### 3. Perform Genetic Algorithm to Solve 8-Queens Problem

# %% [markdown]
# Let's Start by making the neccessary Imports

# %%
from __future__ import division
from random import Random, random

# %% [markdown]
# Let's Define a State or a Chromosome

# %%
class State(object):
    MUTATION_RATE = 0.25
    def __init__(self, parents=None):
        r = Random()
        self._fitness = None
        self._probability = None
        if parents==None:
            self.state = [r.randint(1,8) for y in range(8)]
        else:
            parent1 = parents[0]
            parent2 = parents[1]
            self.state = self.crossover(parent1, parent2)
            self.mutate()

############################################
    def fitness(self):
        state = self.state
        self._fitness = 0
        for i in range(len(state)):
            for j in range(len(state)):
                if i != j:
                    if (abs(i - j) == abs(state[i] - state[j])):
                        self._fitness += 1
                    elif (state[i] == state[j]):
                        self._fitness += 1
        return self._fitness 


############################################
    def crossover(self, parent1, parent2):
        r = Random()
        random_list = r.sample(range(0,8), 2)

        crossover_index1 = min (random_list)
        crossover_index2 = max (random_list)

        crossover_index = r.randint(0,8)
        left = parent1.state[0:crossover_index1]
        mid = parent2.state[crossover_index1:crossover_index2]
        right = parent1.state[crossover_index2:8]
        
        left.extend(mid)
        left.extend(right)

        return left

############################################
    def mutate(self):
        r = Random()
        for i in range(len(self.state)):
            if random() < State.MUTATION_RATE:
                self.state[i] = r.randint(1,8)


############################################
    def __str__(self):
        r = str(self.state)
        print (self.fitness(), self.state)
        return r

############################################
    def probability(self, population):
        if not self._probability:
            self._probability = self.fitness() / sum([x.fitness() for x in population])
        return self._probability

############################################
def pickRandomByProbability(populationByProbability):
    i = 0
    selectedState = None
    while selectedState == None:
        current = populationByProbability[i] 
        if current[0] <= random():
            return current[1]
        if i+1 <= len(populationByProbability):
            i = 0
        else:
            i += 1
############################################
def generateNextPopulation(population, n):
    newPopulation = []
    while len(newPopulation) < n:
        populationByProbability = [(x.probability(population), x) for x in population]
        parent1 = pickRandomByProbability(populationByProbability)
        populationByProbability = [x for x in populationByProbability if x[1] != parent1]
        parent2 = pickRandomByProbability(populationByProbability)
        newPopulation.append(State((parent1, parent2)))
    return newPopulation
############################################

############################################

# %% [markdown]
# Let's Define a function to Calculate the Fitness value of a State/Chromosome for Selection Purposes

# %%
    def fitness(self):
        state = self.state
        self._fitness = 0
        for i in range(len(state)):
            for j in range(len(state)):
                if i != j:
                    if (abs(i - j) == abs(state[i] - state[j])):
                        self._fitness += 1
                    elif (state[i] == state[j]):
                        self._fitness += 1
        return self._fitness

# %% [markdown]
# Let's Define a function to perform Cross-Over on a given State

# %%
    def crossover(self, parent1, parent2):
        r = Random()
        crossover_index = r.randint(0,8)
        left = parent1.state[0:crossover_index]
        right = parent2.state[crossover_index:8]
        left.extend(right)
        return left

# %% [markdown]
# Defininig the Mutation Function to perform mutation on a given Chromosome

# %%
    def mutate(self):
        r = Random()
        for i in range(len(self.state)):
            if random() < State.MUTATION_RATE:
                self.state[i] = r.randint(1,8)

# %%
    def __str__(self):
        r = str(self.state)
        print (self.fitness(), self.state)
        return r

# %% [markdown]
# Calculating the Probabilities of State/Chromosomes for Further Selection/Generation Process

# %%
    def probability(self, population):
        if not self._probability:
            self._probability = self.fitness() / sum([x.fitness() for x in population])
        return self._probability

# %% [markdown]
# Picking the Chromosomes based on their corresponding probabilities

# %%
def pickRandomByProbability(populationByProbability):
    i = 0
    selectedState = None
    while selectedState == None:
        current = populationByProbability[i] 
        if current[0] <= random():
            return current[1]
        if i+1 <= len(populationByProbability):
            i = 0
        else:
            i += 1

# %% [markdown]
# A function to generate the population for next Generation

# %%
def generateNextPopulation(population, n):
    newPopulation = []
    while len(newPopulation) < n:
        populationByProbability = [(x.probability(population), x) for x in population]
        parent1 = pickRandomByProbability(populationByProbability)
        populationByProbability = [x for x in populationByProbability if x[1] != parent1]
        parent2 = pickRandomByProbability(populationByProbability)
        newPopulation.append(State((parent1, parent2)))
    return newPopulation

# %% [markdown]
# Now let's Conclude with the main Driving Function

# %%
if __name__ == '__main__':
    populationSize = 200
    generation = 1
    population = [State() for x in range(populationSize)]
    while not 0 in [x.fitness() for x in population]:
        print ("generation %dt   Min fitness: %d" % (generation, min([x.fitness() for x in population])))
        population = generateNextPopulation(population, populationSize)
        generation += 1
        for x in population:
            if x.fitness() <= 1:
                print (x.state, x.fitness())
# Out:
# generation 1t   Min fitness: 6
# generation 2t   Min fitness: 8
# generation 3t   Min fitness: 6
# generation 4t   Min fitness: 6
# generation 5t   Min fitness: 6
# generation 6t   Min fitness: 4
# generation 7t   Min fitness: 8
# generation 8t   Min fitness: 4
# generation 9t   Min fitness: 10
# generation 10t   Min fitness: 6
# generation 11t   Min fitness: 2
# generation 12t   Min fitness: 6
# generation 13t   Min fitness: 4
# generation 14t   Min fitness: 6
# generation 15t   Min fitness: 4
# generation 16t   Min fitness: 6
# generation 17t   Min fitness: 6
# generation 18t   Min fitness: 10
# generation 19t   Min fitness: 8
# generation 20t   Min fitness: 8
# generation 21t   Min fitness: 8
# generation 22t   Min fitness: 4
# generation 23t   Min fitness: 4
# generation 24t   Min fitness: 8
# generation 25t   Min fitness: 6
# generation 26t   Min fitness: 6
# generation 27t   Min fitness: 4
# generation 28t   Min fitness: 8
# generation 29t   Min fitness: 4
# generation 30t   Min fitness: 6
# generation 31t   Min fitness: 6
# generation 32t   Min fitness: 4
# generation 33t   Min fitness: 6
# generation 34t   Min fitness: 6
# generation 35t   Min fitness: 8
# generation 36t   Min fitness: 6
# generation 37t   Min fitness: 8
# generation 38t   Min fitness: 6
# generation 39t   Min fitness: 6
# generation 40t   Min fitness: 6
# generation 41t   Min fitness: 6
# generation 42t   Min fitness: 6
# generation 43t   Min fitness: 6
# generation 44t   Min fitness: 6
# generation 45t   Min fitness: 4
# generation 46t   Min fitness: 8
# generation 47t   Min fitness: 6
# generation 48t   Min fitness: 6
# generation 49t   Min fitness: 6
# generation 50t   Min fitness: 8
# generation 51t   Min fitness: 8
# generation 52t   Min fitness: 6
# generation 53t   Min fitness: 8
# generation 54t   Min fitness: 6
# generation 55t   Min fitness: 6
# generation 56t   Min fitness: 6
# generation 57t   Min fitness: 6
# generation 58t   Min fitness: 6
# generation 59t   Min fitness: 4
# generation 60t   Min fitness: 4
# generation 61t   Min fitness: 6
# generation 62t   Min fitness: 6
# generation 63t   Min fitness: 8
# generation 64t   Min fitness: 4
# generation 65t   Min fitness: 2
# generation 66t   Min fitness: 2
# generation 67t   Min fitness: 6
# generation 68t   Min fitness: 2
# generation 69t   Min fitness: 6
# generation 70t   Min fitness: 6
# generation 71t   Min fitness: 6
# generation 72t   Min fitness: 4
# generation 73t   Min fitness: 6
# generation 74t   Min fitness: 10
# generation 75t   Min fitness: 8
# generation 76t   Min fitness: 8
# generation 77t   Min fitness: 8
# generation 78t   Min fitness: 6
# generation 79t   Min fitness: 6
# generation 80t   Min fitness: 4
# generation 81t   Min fitness: 2
# generation 82t   Min fitness: 6
# generation 83t   Min fitness: 6
# generation 84t   Min fitness: 6
# generation 85t   Min fitness: 6
# generation 86t   Min fitness: 6
# generation 87t   Min fitness: 4
# generation 88t   Min fitness: 4
# generation 89t   Min fitness: 4
# generation 90t   Min fitness: 6
# generation 91t   Min fitness: 4
# generation 92t   Min fitness: 6
# generation 93t   Min fitness: 6
# generation 94t   Min fitness: 6
# generation 95t   Min fitness: 6
# generation 96t   Min fitness: 6
# generation 97t   Min fitness: 8
# generation 98t   Min fitness: 6
# generation 99t   Min fitness: 6
# generation 100t   Min fitness: 6
# generation 101t   Min fitness: 8
# generation 102t   Min fitness: 6
# generation 103t   Min fitness: 4
# generation 104t   Min fitness: 8
# generation 105t   Min fitness: 6
# generation 106t   Min fitness: 8
# generation 107t   Min fitness: 6
# generation 108t   Min fitness: 6
# generation 109t   Min fitness: 6
# generation 110t   Min fitness: 6
# generation 111t   Min fitness: 8
# generation 112t   Min fitness: 8
# generation 113t   Min fitness: 8
# generation 114t   Min fitness: 4
# generation 115t   Min fitness: 4
# generation 116t   Min fitness: 6
# generation 117t   Min fitness: 4
# generation 118t   Min fitness: 4
# generation 119t   Min fitness: 6
# generation 120t   Min fitness: 6
# generation 121t   Min fitness: 6
# generation 122t   Min fitness: 6
# generation 123t   Min fitness: 4
# generation 124t   Min fitness: 6
# generation 125t   Min fitness: 4
# generation 126t   Min fitness: 8
# generation 127t   Min fitness: 6
# generation 128t   Min fitness: 8
# generation 129t   Min fitness: 6
# generation 130t   Min fitness: 8
# generation 131t   Min fitness: 6
# generation 132t   Min fitness: 8
# generation 133t   Min fitness: 8
# generation 134t   Min fitness: 8
# generation 135t   Min fitness: 8
# generation 136t   Min fitness: 6
# generation 137t   Min fitness: 4
# generation 138t   Min fitness: 2
# generation 139t   Min fitness: 6
# generation 140t   Min fitness: 4
# generation 141t   Min fitness: 6
# generation 142t   Min fitness: 4
# generation 143t   Min fitness: 4
# generation 144t   Min fitness: 8
# generation 145t   Min fitness: 4
# generation 146t   Min fitness: 4
# generation 147t   Min fitness: 4
# generation 148t   Min fitness: 4
# generation 149t   Min fitness: 8
# generation 150t   Min fitness: 6
# generation 151t   Min fitness: 8
# generation 152t   Min fitness: 4
# generation 153t   Min fitness: 6
# generation 154t   Min fitness: 6
# generation 155t   Min fitness: 6
# generation 156t   Min fitness: 6
# generation 157t   Min fitness: 6
# generation 158t   Min fitness: 6
# generation 159t   Min fitness: 4
# generation 160t   Min fitness: 6
# generation 161t   Min fitness: 6
# generation 162t   Min fitness: 6
# generation 163t   Min fitness: 4
# generation 164t   Min fitness: 4
# generation 165t   Min fitness: 4
# generation 166t   Min fitness: 2
# generation 167t   Min fitness: 2
# generation 168t   Min fitness: 2
# generation 169t   Min fitness: 4
# generation 170t   Min fitness: 6
# generation 171t   Min fitness: 6
# generation 172t   Min fitness: 2
# generation 173t   Min fitness: 6
# generation 174t   Min fitness: 8
# generation 175t   Min fitness: 4
# generation 176t   Min fitness: 10
# generation 177t   Min fitness: 4
# generation 178t   Min fitness: 8
# generation 179t   Min fitness: 8
# generation 180t   Min fitness: 8
# generation 181t   Min fitness: 8
# generation 182t   Min fitness: 8
# generation 183t   Min fitness: 8
# generation 184t   Min fitness: 8
# generation 185t   Min fitness: 6
# generation 186t   Min fitness: 8
# generation 187t   Min fitness: 4
# generation 188t   Min fitness: 4
# generation 189t   Min fitness: 6
# generation 190t   Min fitness: 10
# generation 191t   Min fitness: 10
# generation 192t   Min fitness: 6
# generation 193t   Min fitness: 2
# generation 194t   Min fitness: 4
# generation 195t   Min fitness: 6
# generation 196t   Min fitness: 6
# generation 197t   Min fitness: 6
# generation 198t   Min fitness: 8
# generation 199t   Min fitness: 4
# generation 200t   Min fitness: 6
# generation 201t   Min fitness: 6
# generation 202t   Min fitness: 4
# generation 203t   Min fitness: 4
# generation 204t   Min fitness: 8
# generation 205t   Min fitness: 8
# generation 206t   Min fitness: 4
# generation 207t   Min fitness: 4
# generation 208t   Min fitness: 6
# generation 209t   Min fitness: 4
# generation 210t   Min fitness: 6
# generation 211t   Min fitness: 10
# generation 212t   Min fitness: 4
# generation 213t   Min fitness: 8
# generation 214t   Min fitness: 8
# generation 215t   Min fitness: 6
# generation 216t   Min fitness: 4
# generation 217t   Min fitness: 8
# generation 218t   Min fitness: 6
# generation 219t   Min fitness: 6
# generation 220t   Min fitness: 6
# generation 221t   Min fitness: 8
# generation 222t   Min fitness: 8
# generation 223t   Min fitness: 4
# generation 224t   Min fitness: 6
# generation 225t   Min fitness: 6
# generation 226t   Min fitness: 6
# generation 227t   Min fitness: 6
# generation 228t   Min fitness: 6
# generation 229t   Min fitness: 6
# generation 230t   Min fitness: 6
# generation 231t   Min fitness: 4
# generation 232t   Min fitness: 4
# generation 233t   Min fitness: 8
# generation 234t   Min fitness: 8
# generation 235t   Min fitness: 6
# generation 236t   Min fitness: 10
# generation 237t   Min fitness: 8
# generation 238t   Min fitness: 6
# generation 239t   Min fitness: 4
# generation 240t   Min fitness: 4
# generation 241t   Min fitness: 6
# generation 242t   Min fitness: 6
# generation 243t   Min fitness: 6
# generation 244t   Min fitness: 6
# generation 245t   Min fitness: 6
# generation 246t   Min fitness: 6
# generation 247t   Min fitness: 6
# generation 248t   Min fitness: 4
# generation 249t   Min fitness: 6
# generation 250t   Min fitness: 4
# generation 251t   Min fitness: 6
# generation 252t   Min fitness: 8
# generation 253t   Min fitness: 4
# generation 254t   Min fitness: 6
# generation 255t   Min fitness: 2
# generation 256t   Min fitness: 6
# generation 257t   Min fitness: 4
# generation 258t   Min fitness: 4
# generation 259t   Min fitness: 8
# generation 260t   Min fitness: 2
# generation 261t   Min fitness: 4
# generation 262t   Min fitness: 6
# generation 263t   Min fitness: 4
# generation 264t   Min fitness: 6
# generation 265t   Min fitness: 2
# generation 266t   Min fitness: 4
# generation 267t   Min fitness: 6
# generation 268t   Min fitness: 6
# generation 269t   Min fitness: 6
# generation 270t   Min fitness: 6
# generation 271t   Min fitness: 6
# generation 272t   Min fitness: 8
# generation 273t   Min fitness: 6
# generation 274t   Min fitness: 8
# generation 275t   Min fitness: 8
# generation 276t   Min fitness: 8
# generation 277t   Min fitness: 6
# generation 278t   Min fitness: 6
# generation 279t   Min fitness: 6
# generation 280t   Min fitness: 6
# generation 281t   Min fitness: 6
# generation 282t   Min fitness: 4
# generation 283t   Min fitness: 6
# generation 284t   Min fitness: 4
# generation 285t   Min fitness: 8
# generation 286t   Min fitness: 8
# generation 287t   Min fitness: 8
# generation 288t   Min fitness: 8
# generation 289t   Min fitness: 4
# generation 290t   Min fitness: 8
# generation 291t   Min fitness: 4
# generation 292t   Min fitness: 8
# generation 293t   Min fitness: 8
# generation 294t   Min fitness: 6
# generation 295t   Min fitness: 8
# generation 296t   Min fitness: 6
# generation 297t   Min fitness: 10
# generation 298t   Min fitness: 8
# generation 299t   Min fitness: 8
# generation 300t   Min fitness: 6
# generation 301t   Min fitness: 4
# generation 302t   Min fitness: 6
# generation 303t   Min fitness: 10
# generation 304t   Min fitness: 8
# generation 305t   Min fitness: 4
# generation 306t   Min fitness: 8
# generation 307t   Min fitness: 8
# generation 308t   Min fitness: 6
# generation 309t   Min fitness: 8
# generation 310t   Min fitness: 6
# generation 311t   Min fitness: 4
# generation 312t   Min fitness: 4
# generation 313t   Min fitness: 6
# generation 314t   Min fitness: 6
# generation 315t   Min fitness: 6
# generation 316t   Min fitness: 6
# generation 317t   Min fitness: 6
# generation 318t   Min fitness: 6
# generation 319t   Min fitness: 6
# generation 320t   Min fitness: 6
# generation 321t   Min fitness: 6
# generation 322t   Min fitness: 8
# generation 323t   Min fitness: 6
# generation 324t   Min fitness: 4
# generation 325t   Min fitness: 6
# generation 326t   Min fitness: 6
# generation 327t   Min fitness: 8
# generation 328t   Min fitness: 6
# generation 329t   Min fitness: 4
# generation 330t   Min fitness: 6
# generation 331t   Min fitness: 6
# generation 332t   Min fitness: 6
# generation 333t   Min fitness: 6
# generation 334t   Min fitness: 6
# generation 335t   Min fitness: 6
# generation 336t   Min fitness: 4
# generation 337t   Min fitness: 6
# generation 338t   Min fitness: 8
# generation 339t   Min fitness: 6
# generation 340t   Min fitness: 6
# generation 341t   Min fitness: 4
# generation 342t   Min fitness: 8
# generation 343t   Min fitness: 6
# generation 344t   Min fitness: 8
# generation 345t   Min fitness: 6
# generation 346t   Min fitness: 8
# generation 347t   Min fitness: 8
# generation 348t   Min fitness: 8
# generation 349t   Min fitness: 6
# generation 350t   Min fitness: 6
# generation 351t   Min fitness: 6
# generation 352t   Min fitness: 6
# generation 353t   Min fitness: 6
# generation 354t   Min fitness: 4
# generation 355t   Min fitness: 6
# generation 356t   Min fitness: 6
# generation 357t   Min fitness: 4
# generation 358t   Min fitness: 2
# generation 359t   Min fitness: 4
# generation 360t   Min fitness: 4
# generation 361t   Min fitness: 6
# generation 362t   Min fitness: 6
# generation 363t   Min fitness: 6
# generation 364t   Min fitness: 6
# generation 365t   Min fitness: 8
# generation 366t   Min fitness: 6
# generation 367t   Min fitness: 6
# generation 368t   Min fitness: 8
# generation 369t   Min fitness: 6
# generation 370t   Min fitness: 6
# generation 371t   Min fitness: 6
# generation 372t   Min fitness: 8
# generation 373t   Min fitness: 8
# generation 374t   Min fitness: 8
# generation 375t   Min fitness: 8
# generation 376t   Min fitness: 6
# generation 377t   Min fitness: 8
# generation 378t   Min fitness: 6
# generation 379t   Min fitness: 6
# generation 380t   Min fitness: 4
# generation 381t   Min fitness: 6
# generation 382t   Min fitness: 6
# generation 383t   Min fitness: 6
# generation 384t   Min fitness: 8
# generation 385t   Min fitness: 8
# generation 386t   Min fitness: 6
# generation 387t   Min fitness: 8
# generation 388t   Min fitness: 8
# generation 389t   Min fitness: 8
# generation 390t   Min fitness: 6
# generation 391t   Min fitness: 2
# generation 392t   Min fitness: 4
# generation 393t   Min fitness: 6
# generation 394t   Min fitness: 4
# generation 395t   Min fitness: 8
# generation 396t   Min fitness: 6
# generation 397t   Min fitness: 6
# generation 398t   Min fitness: 4
# generation 399t   Min fitness: 6
# generation 400t   Min fitness: 2
# generation 401t   Min fitness: 6
# generation 402t   Min fitness: 6
# generation 403t   Min fitness: 8
# generation 404t   Min fitness: 8
# generation 405t   Min fitness: 4
# generation 406t   Min fitness: 8
# generation 407t   Min fitness: 8
# generation 408t   Min fitness: 6
# generation 409t   Min fitness: 8
# generation 410t   Min fitness: 8
# generation 411t   Min fitness: 6
# generation 412t   Min fitness: 4
# generation 413t   Min fitness: 6
# generation 414t   Min fitness: 8
# generation 415t   Min fitness: 4
# generation 416t   Min fitness: 6
# generation 417t   Min fitness: 8
# generation 418t   Min fitness: 8
# generation 419t   Min fitness: 8
# generation 420t   Min fitness: 6
# generation 421t   Min fitness: 6
# generation 422t   Min fitness: 6
# generation 423t   Min fitness: 4
# generation 424t   Min fitness: 6
# generation 425t   Min fitness: 4
# generation 426t   Min fitness: 4
# generation 427t   Min fitness: 4
# generation 428t   Min fitness: 6
# generation 429t   Min fitness: 6
# generation 430t   Min fitness: 8
# generation 431t   Min fitness: 6
# generation 432t   Min fitness: 6
# generation 433t   Min fitness: 4
# generation 434t   Min fitness: 6
# generation 435t   Min fitness: 4
# generation 436t   Min fitness: 6
# generation 437t   Min fitness: 6
# generation 438t   Min fitness: 8
# generation 439t   Min fitness: 6
# generation 440t   Min fitness: 6
# generation 441t   Min fitness: 4
# generation 442t   Min fitness: 6
# generation 443t   Min fitness: 8
# generation 444t   Min fitness: 8
# generation 445t   Min fitness: 6
# generation 446t   Min fitness: 6
# generation 447t   Min fitness: 6
# generation 448t   Min fitness: 8
# generation 449t   Min fitness: 6
# generation 450t   Min fitness: 4
# generation 451t   Min fitness: 4
# generation 452t   Min fitness: 10
# generation 453t   Min fitness: 6
# generation 454t   Min fitness: 8
# generation 455t   Min fitness: 4
# generation 456t   Min fitness: 6
# generation 457t   Min fitness: 4
# generation 458t   Min fitness: 8
# generation 459t   Min fitness: 4
# generation 460t   Min fitness: 4
# generation 461t   Min fitness: 8
# generation 462t   Min fitness: 10
# generation 463t   Min fitness: 10
# generation 464t   Min fitness: 8
# generation 465t   Min fitness: 6
# generation 466t   Min fitness: 8
# generation 467t   Min fitness: 6
# generation 468t   Min fitness: 8
# generation 469t   Min fitness: 6
# generation 470t   Min fitness: 10
# generation 471t   Min fitness: 6
# generation 472t   Min fitness: 6
# generation 473t   Min fitness: 8
# generation 474t   Min fitness: 4
# generation 475t   Min fitness: 8
# generation 476t   Min fitness: 8
# generation 477t   Min fitness: 8
# generation 478t   Min fitness: 6
# generation 479t   Min fitness: 6
# generation 480t   Min fitness: 4
# generation 481t   Min fitness: 4
# generation 482t   Min fitness: 4
# generation 483t   Min fitness: 6
# generation 484t   Min fitness: 6
# generation 485t   Min fitness: 8
# generation 486t   Min fitness: 6
# generation 487t   Min fitness: 2
# generation 488t   Min fitness: 6
# generation 489t   Min fitness: 6
# generation 490t   Min fitness: 4
# generation 491t   Min fitness: 6
# generation 492t   Min fitness: 6
# generation 493t   Min fitness: 4
# generation 494t   Min fitness: 6
# generation 495t   Min fitness: 6
# generation 496t   Min fitness: 4
# generation 497t   Min fitness: 6
# generation 498t   Min fitness: 6
# generation 499t   Min fitness: 4
# generation 500t   Min fitness: 4
# generation 501t   Min fitness: 6
# generation 502t   Min fitness: 6
# generation 503t   Min fitness: 8
# generation 504t   Min fitness: 8
# generation 505t   Min fitness: 4
# generation 506t   Min fitness: 4
# generation 507t   Min fitness: 8
# generation 508t   Min fitness: 6
# generation 509t   Min fitness: 6
# generation 510t   Min fitness: 6
# generation 511t   Min fitness: 8
# generation 512t   Min fitness: 4
# generation 513t   Min fitness: 8
# generation 514t   Min fitness: 6
# generation 515t   Min fitness: 8
# generation 516t   Min fitness: 6
# generation 517t   Min fitness: 6
# generation 518t   Min fitness: 8
# generation 519t   Min fitness: 4
# generation 520t   Min fitness: 6
# generation 521t   Min fitness: 6
# generation 522t   Min fitness: 8
# generation 523t   Min fitness: 6
# generation 524t   Min fitness: 4
# generation 525t   Min fitness: 4
# generation 526t   Min fitness: 4
# generation 527t   Min fitness: 6
# generation 528t   Min fitness: 4
# generation 529t   Min fitness: 6
# generation 530t   Min fitness: 4
# generation 531t   Min fitness: 6
# generation 532t   Min fitness: 4
# generation 533t   Min fitness: 6
# generation 534t   Min fitness: 6
# generation 535t   Min fitness: 6
# generation 536t   Min fitness: 6
# generation 537t   Min fitness: 10
# generation 538t   Min fitness: 8
# generation 539t   Min fitness: 8
# generation 540t   Min fitness: 8
# generation 541t   Min fitness: 6
# generation 542t   Min fitness: 6
# generation 543t   Min fitness: 4
# generation 544t   Min fitness: 6
# generation 545t   Min fitness: 6
# generation 546t   Min fitness: 6
# generation 547t   Min fitness: 8
# generation 548t   Min fitness: 6
# generation 549t   Min fitness: 6
# generation 550t   Min fitness: 6
# generation 551t   Min fitness: 8
# generation 552t   Min fitness: 6
# generation 553t   Min fitness: 6
# generation 554t   Min fitness: 4
# generation 555t   Min fitness: 6
# generation 556t   Min fitness: 6
# generation 557t   Min fitness: 6
# generation 558t   Min fitness: 8
# generation 559t   Min fitness: 4
# generation 560t   Min fitness: 6
# generation 561t   Min fitness: 4
# generation 562t   Min fitness: 4
# generation 563t   Min fitness: 6
# generation 564t   Min fitness: 6
# generation 565t   Min fitness: 4
# generation 566t   Min fitness: 6
# generation 567t   Min fitness: 6
# generation 568t   Min fitness: 6
# generation 569t   Min fitness: 4
# generation 570t   Min fitness: 8
# generation 571t   Min fitness: 4
# generation 572t   Min fitness: 8
# generation 573t   Min fitness: 8
# generation 574t   Min fitness: 6
# generation 575t   Min fitness: 6
# generation 576t   Min fitness: 4
# generation 577t   Min fitness: 6
# generation 578t   Min fitness: 4
# generation 579t   Min fitness: 6
# generation 580t   Min fitness: 6
# generation 581t   Min fitness: 2
# generation 582t   Min fitness: 8
# generation 583t   Min fitness: 6
# generation 584t   Min fitness: 8
# generation 585t   Min fitness: 4
# generation 586t   Min fitness: 8
# generation 587t   Min fitness: 6
# generation 588t   Min fitness: 6
# generation 589t   Min fitness: 6
# generation 590t   Min fitness: 4
# generation 591t   Min fitness: 6
# generation 592t   Min fitness: 6
# generation 593t   Min fitness: 8
# generation 594t   Min fitness: 4
# generation 595t   Min fitness: 8
# generation 596t   Min fitness: 8
# generation 597t   Min fitness: 4
# generation 598t   Min fitness: 6
# generation 599t   Min fitness: 6
# generation 600t   Min fitness: 8
# generation 601t   Min fitness: 6
# generation 602t   Min fitness: 6
# generation 603t   Min fitness: 6
# generation 604t   Min fitness: 6
# generation 605t   Min fitness: 4
# generation 606t   Min fitness: 6
# generation 607t   Min fitness: 8
# generation 608t   Min fitness: 8
# generation 609t   Min fitness: 6
# generation 610t   Min fitness: 6
# generation 611t   Min fitness: 6
# generation 612t   Min fitness: 4
# generation 613t   Min fitness: 6
# generation 614t   Min fitness: 6
# generation 615t   Min fitness: 4
# generation 616t   Min fitness: 6
# generation 617t   Min fitness: 6
# generation 618t   Min fitness: 6
# generation 619t   Min fitness: 6
# generation 620t   Min fitness: 4
# generation 621t   Min fitness: 4
# generation 622t   Min fitness: 4
# generation 623t   Min fitness: 6
# generation 624t   Min fitness: 6
# generation 625t   Min fitness: 6
# generation 626t   Min fitness: 8
# generation 627t   Min fitness: 6
# generation 628t   Min fitness: 6
# generation 629t   Min fitness: 6
# generation 630t   Min fitness: 4
# generation 631t   Min fitness: 6
# generation 632t   Min fitness: 8
# generation 633t   Min fitness: 8
# generation 634t   Min fitness: 8
# generation 635t   Min fitness: 4
# generation 636t   Min fitness: 8
# generation 637t   Min fitness: 6
# generation 638t   Min fitness: 10
# generation 639t   Min fitness: 6
# generation 640t   Min fitness: 8
# generation 641t   Min fitness: 6
# generation 642t   Min fitness: 4
# generation 643t   Min fitness: 4
# generation 644t   Min fitness: 4
# generation 645t   Min fitness: 6
# generation 646t   Min fitness: 4
# generation 647t   Min fitness: 6
# generation 648t   Min fitness: 6
# generation 649t   Min fitness: 6
# generation 650t   Min fitness: 8
# generation 651t   Min fitness: 8
# generation 652t   Min fitness: 4
# generation 653t   Min fitness: 4
# generation 654t   Min fitness: 4
# generation 655t   Min fitness: 6
# generation 656t   Min fitness: 6
# generation 657t   Min fitness: 6
# generation 658t   Min fitness: 4
# generation 659t   Min fitness: 4
# generation 660t   Min fitness: 6
# generation 661t   Min fitness: 6
# generation 662t   Min fitness: 4
# generation 663t   Min fitness: 4
# generation 664t   Min fitness: 4
# generation 665t   Min fitness: 4
# generation 666t   Min fitness: 2
# generation 667t   Min fitness: 4
# generation 668t   Min fitness: 8
# generation 669t   Min fitness: 8
# generation 670t   Min fitness: 4
# generation 671t   Min fitness: 4
# generation 672t   Min fitness: 6
# generation 673t   Min fitness: 8
# generation 674t   Min fitness: 6
# generation 675t   Min fitness: 8
# generation 676t   Min fitness: 6
# generation 677t   Min fitness: 4
# generation 678t   Min fitness: 4
# generation 679t   Min fitness: 6
# generation 680t   Min fitness: 6
# generation 681t   Min fitness: 4
# generation 682t   Min fitness: 6
# generation 683t   Min fitness: 6
# generation 684t   Min fitness: 6
# generation 685t   Min fitness: 6
# generation 686t   Min fitness: 6
# generation 687t   Min fitness: 8
# generation 688t   Min fitness: 6
# generation 689t   Min fitness: 8
# generation 690t   Min fitness: 8
# generation 691t   Min fitness: 4
# generation 692t   Min fitness: 4
# generation 693t   Min fitness: 10
# generation 694t   Min fitness: 10
# generation 695t   Min fitness: 6
# generation 696t   Min fitness: 6
# generation 697t   Min fitness: 6
# generation 698t   Min fitness: 4
# generation 699t   Min fitness: 4
# generation 700t   Min fitness: 4
# generation 701t   Min fitness: 6
# generation 702t   Min fitness: 6
# generation 703t   Min fitness: 8
# generation 704t   Min fitness: 6
# generation 705t   Min fitness: 6
# generation 706t   Min fitness: 6
# generation 707t   Min fitness: 6
# generation 708t   Min fitness: 6
# generation 709t   Min fitness: 8
# generation 710t   Min fitness: 6
# generation 711t   Min fitness: 6
# generation 712t   Min fitness: 4
# generation 713t   Min fitness: 6
# generation 714t   Min fitness: 6
# generation 715t   Min fitness: 6
# generation 716t   Min fitness: 6
# generation 717t   Min fitness: 8
# generation 718t   Min fitness: 6
# generation 719t   Min fitness: 4
# generation 720t   Min fitness: 6
# generation 721t   Min fitness: 8
# generation 722t   Min fitness: 8
# generation 723t   Min fitness: 8
# generation 724t   Min fitness: 8
# generation 725t   Min fitness: 4
# generation 726t   Min fitness: 6
# generation 727t   Min fitness: 8
# generation 728t   Min fitness: 4
# generation 729t   Min fitness: 4
# generation 730t   Min fitness: 6
# generation 731t   Min fitness: 4
# generation 732t   Min fitness: 4
# generation 733t   Min fitness: 2
# generation 734t   Min fitness: 4
# generation 735t   Min fitness: 4
# generation 736t   Min fitness: 6
# generation 737t   Min fitness: 6
# generation 738t   Min fitness: 6
# generation 739t   Min fitness: 8
# generation 740t   Min fitness: 6
# generation 741t   Min fitness: 6
# generation 742t   Min fitness: 8
# generation 743t   Min fitness: 6
# generation 744t   Min fitness: 4
# generation 745t   Min fitness: 6
# generation 746t   Min fitness: 6
# generation 747t   Min fitness: 8
# generation 748t   Min fitness: 8
# generation 749t   Min fitness: 4
# generation 750t   Min fitness: 6
# generation 751t   Min fitness: 4
# generation 752t   Min fitness: 6
# generation 753t   Min fitness: 6
# generation 754t   Min fitness: 4
# generation 755t   Min fitness: 4
# generation 756t   Min fitness: 4
# generation 757t   Min fitness: 4
# generation 758t   Min fitness: 8
# generation 759t   Min fitness: 8
# generation 760t   Min fitness: 8
# generation 761t   Min fitness: 8
# generation 762t   Min fitness: 8
# generation 763t   Min fitness: 6
# generation 764t   Min fitness: 4
# generation 765t   Min fitness: 6
# generation 766t   Min fitness: 8
# generation 767t   Min fitness: 6
# generation 768t   Min fitness: 4
# generation 769t   Min fitness: 6
# generation 770t   Min fitness: 6
# generation 771t   Min fitness: 4
# generation 772t   Min fitness: 8
# generation 773t   Min fitness: 6
# generation 774t   Min fitness: 4
# generation 775t   Min fitness: 8
# generation 776t   Min fitness: 6
# generation 777t   Min fitness: 6
# generation 778t   Min fitness: 6
# generation 779t   Min fitness: 6
# generation 780t   Min fitness: 4
# generation 781t   Min fitness: 6
# generation 782t   Min fitness: 4
# generation 783t   Min fitness: 4
# generation 784t   Min fitness: 4
# generation 785t   Min fitness: 6
# generation 786t   Min fitness: 6
# generation 787t   Min fitness: 4
# generation 788t   Min fitness: 6
# generation 789t   Min fitness: 6
# generation 790t   Min fitness: 6
# generation 791t   Min fitness: 6
# generation 792t   Min fitness: 6
# generation 793t   Min fitness: 2
# generation 794t   Min fitness: 6
# generation 795t   Min fitness: 4
# generation 796t   Min fitness: 6
# generation 797t   Min fitness: 6
# generation 798t   Min fitness: 6
# generation 799t   Min fitness: 4
# generation 800t   Min fitness: 6
# generation 801t   Min fitness: 4
# generation 802t   Min fitness: 2
# generation 803t   Min fitness: 8
# generation 804t   Min fitness: 8
# generation 805t   Min fitness: 6
# generation 806t   Min fitness: 6
# generation 807t   Min fitness: 6
# generation 808t   Min fitness: 4
# generation 809t   Min fitness: 4
# generation 810t   Min fitness: 4
# generation 811t   Min fitness: 4
# generation 812t   Min fitness: 4
# generation 813t   Min fitness: 8
# generation 814t   Min fitness: 6
# generation 815t   Min fitness: 4
# generation 816t   Min fitness: 6
# generation 817t   Min fitness: 4
# generation 818t   Min fitness: 8
# generation 819t   Min fitness: 6
# generation 820t   Min fitness: 6
# generation 821t   Min fitness: 6
# generation 822t   Min fitness: 4
# generation 823t   Min fitness: 4
# generation 824t   Min fitness: 6
# generation 825t   Min fitness: 8
# generation 826t   Min fitness: 6
# generation 827t   Min fitness: 6
# generation 828t   Min fitness: 6
# generation 829t   Min fitness: 6
# generation 830t   Min fitness: 6
# generation 831t   Min fitness: 6
# generation 832t   Min fitness: 6
# generation 833t   Min fitness: 4
# generation 834t   Min fitness: 6
# generation 835t   Min fitness: 8
# generation 836t   Min fitness: 6
# generation 837t   Min fitness: 4
# generation 838t   Min fitness: 6
# generation 839t   Min fitness: 8
# generation 840t   Min fitness: 8
# generation 841t   Min fitness: 10
# generation 842t   Min fitness: 8
# generation 843t   Min fitness: 6
# generation 844t   Min fitness: 6
# generation 845t   Min fitness: 6
# generation 846t   Min fitness: 4
# generation 847t   Min fitness: 8
# generation 848t   Min fitness: 8
# generation 849t   Min fitness: 6
# generation 850t   Min fitness: 6
# generation 851t   Min fitness: 8
# generation 852t   Min fitness: 8
# generation 853t   Min fitness: 8
# generation 854t   Min fitness: 6
# generation 855t   Min fitness: 8
# generation 856t   Min fitness: 6
# generation 857t   Min fitness: 6
# generation 858t   Min fitness: 6
# generation 859t   Min fitness: 6
# generation 860t   Min fitness: 8
# generation 861t   Min fitness: 8
# generation 862t   Min fitness: 10
# generation 863t   Min fitness: 8
# generation 864t   Min fitness: 6
# generation 865t   Min fitness: 8
# generation 866t   Min fitness: 6
# generation 867t   Min fitness: 6
# generation 868t   Min fitness: 6
# generation 869t   Min fitness: 6
# generation 870t   Min fitness: 4
# generation 871t   Min fitness: 6
# generation 872t   Min fitness: 8
# generation 873t   Min fitness: 8
# generation 874t   Min fitness: 4
# generation 875t   Min fitness: 6
# generation 876t   Min fitness: 6
# generation 877t   Min fitness: 8
# generation 878t   Min fitness: 6
# generation 879t   Min fitness: 6
# generation 880t   Min fitness: 6
# generation 881t   Min fitness: 8
# generation 882t   Min fitness: 8
# generation 883t   Min fitness: 10
# generation 884t   Min fitness: 8
# generation 885t   Min fitness: 4
# generation 886t   Min fitness: 6
# generation 887t   Min fitness: 8
# generation 888t   Min fitness: 8
# generation 889t   Min fitness: 10
# generation 890t   Min fitness: 8
# generation 891t   Min fitness: 6
# generation 892t   Min fitness: 8
# generation 893t   Min fitness: 8
# generation 894t   Min fitness: 10
# generation 895t   Min fitness: 6
# generation 896t   Min fitness: 6
# generation 897t   Min fitness: 6
# generation 898t   Min fitness: 4
# generation 899t   Min fitness: 4
# generation 900t   Min fitness: 6
# generation 901t   Min fitness: 6
# generation 902t   Min fitness: 6
# generation 903t   Min fitness: 6
# generation 904t   Min fitness: 6
# generation 905t   Min fitness: 6
# generation 906t   Min fitness: 6
# generation 907t   Min fitness: 4
# generation 908t   Min fitness: 6
# generation 909t   Min fitness: 8
# generation 910t   Min fitness: 6
# generation 911t   Min fitness: 8
# generation 912t   Min fitness: 6
# generation 913t   Min fitness: 6
